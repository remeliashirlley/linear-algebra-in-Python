# %% [markdown]
# # Matrices

# %% [markdown]
# ## Exercise 1 : Computer Graphics - Linear Transformations

# %% [markdown]
# #### Question 1
# Plot points a,b,c and d

# %%
import matplotlib.pyplot as plt
import numpy as np
import string

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])

# 3x3 Identity transformation matrix
I = np.eye(3) #float

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    output_row = I @ row
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# #### Question 2
# Perform the following transformations:

# %% [markdown]
# (i) scaling transformation with scale of 2

# %%
scalemat=np.array([[2,0,0],[0,2,0],[0,0,1]])

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    output_row = scalemat @ row
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# (ii) rotation transformation with 90°

# %%
rotmat=np.array([[0,1,0],[-1,0,0],[0,0,1]])

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    output_row = rotmat @ row
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# (iii) translation, horizontal shear and vertical shear using your own parameters

# %% [markdown]
# horizontal shear of 3

# %%
hshear=np.array([[1,3,0],[0,1,0],[0,0,1]])

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    output_row = hshear @ row
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# vertical shear of 3

# %%
vshear=np.array([[1,0,0],[3,1,0],[0,0,1]])

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    output_row = vshear @ row
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# #### Question 3
# Modify the code to implement a combination of the rotation and scaling transformations, i.e., a rotation followed by scaling. Note that since the transformations are linear, a combination of transformations is represented simply as a product of the matrices representing the individual transformation.

# %%
scalemat=np.array([[2,0,0],[0,2,0],[0,0,1]])
rotmat=np.array([[0,1,0],[-1,0,0],[0,0,1]])

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    output_row = rotmat @ row
    output_row = scalemat @ output_row
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# ## Exercise 2: Web Search - PageRank

# %% [markdown]
# #### Question 4
# Google’s search algorithm to rank web pages, also called PageRank algorithm, is based on the following question: in a particular group of people, who is the most popular? Let us say there are 4 people – Alpha, Bravo, Charlie, Delta – who we will call A, B, C and D. Everyone in the group is asked to list their friends in this group. The outcome is as follows: A lists B and C; B lists A, C and D; C lists A, B and D; D lists A and C. Some people might list every one they ever met and others only list closest friends. This is compensated by normalizing the matrix, i.e., by dividing each list by the number of people in it to obtain the linking matrix. Next, we associate a non-negative number to each person that reflects that person’s popularity and collects all the numbers into a popularity vector r. Use a linking matrix to find rA, rB and rC

# %%
#Transform a matrix to reduced row echelon form
 
import numpy as np

'''Function to transform a matrix to reduced row echelon form'''
def rref(A):
    tol = 1e-14
    #A = B.copy()
    rows, cols = A.shape
    r = 0
    pivots_pos = []
    row_exchanges = np.arange(rows)
    for c in range(cols):
        ## Find the pivot row:
        pivot = np.argmax (np.abs (A[r:rows,c])) + r
        m = np.abs(A[pivot, c])
        if m <= tol:
        ## Skip column c, making sure the approximately zero terms are
        ## actually zero.
            A[r:rows, c] = np.zeros(rows-r)
        else:
            ## keep track of bound variables
            pivots_pos.append((r,c))

            if pivot != r:
                ## Swap current row and pivot row
                A[[pivot, r], c:cols] = A[[r, pivot], c:cols]
                row_exchanges[[pivot,r]] = row_exchanges[[r,pivot]]

            ## Normalize pivot row
            A[r, c:cols] = A[r, c:cols] / A[r, c];

            ## Eliminate the current column
            v = A[r, c:cols]
            ## Above (before row r):
            if r > 0:
                ridx_above = np.arange(r)
                A[ridx_above, c:cols] = A[ridx_above, c:cols] - np.outer(v, A[ridx_above, c]).T
                ## Below (after row r):
            if r < rows-1:
                ridx_below = np.arange(r+1,rows)
                A[ridx_below, c:cols] = A[ridx_below, c:cols] - np.outer(v, A[ridx_below, c]).T
                r += 1
        ## Check if done
        if r == rows:
            break;
    return A

# %%
L=np.array([[0, 1/3, 1/3, 1/2],
           [1/2, 0, 1/3, 0],
           [1/2, 1/3, 0, 1/2],
           [0, 1/3, 1/3, 0]])
I=np.eye(4)
Z=np.zeros((4,1))
Aug=np.hstack(((L-I),Z))
print(Aug)
# Out:
# [[-1.          0.33333333  0.33333333  0.5         0.        ]
#  [ 0.5        -1.          0.33333333  0.          0.        ]
#  [ 0.5         0.33333333 -1.          0.5         0.        ]
#  [ 0.          0.33333333  0.33333333 -1.          0.        ]]

# %%
reducedAug=rref(Aug)
print(reducedAug)
rA= - Aug[0][3]
rB= - Aug[1][3]
rC= - Aug[2][3]
rD= 1

print("rA=",rA)
print("rB=",rB)
print("rC=",rC)
print("rD=",rD)
# Out:
# [[ 1.      0.      0.     -1.5    -0.    ]
#  [ 0.      1.      0.     -1.3125 -0.    ]
#  [ 0.      0.      1.     -1.6875 -0.    ]
#  [ 0.      0.      0.      0.      0.    ]]
# rA= 1.5
# rB= 1.3124999999999998
# rC= 1.6874999999999998
# rD= 1

# %% [markdown]
# (a) Does the equation Lr = r above always have a solution? <br>
#     Yes.<br>
# (b) Will a solution have entries that are nonnegative?<br>
#     Yes.<br>
# (c) Is the solution unique? If not, we will have conflicting rankings.<br>
#     No, there's only 3 pivots. The last column does not have a pivot.

# %% [markdown]
# #### Question 5
# Suppose that we have five websites A, B, C, D, and E. Let's also suppose that the links between the various sites are given by the graph below. The arrow pointing from C to D means that C's site links to D's, etc <br>
#     • Create a linking matrix L which contains the information of which site links to which just as you did in the popularity example. Remember to normalize, and be sure that your input is exact (for example, make sure you enter 1/3 instead of .333 since our columns must sum to 1).<br>
#     • Find all solutions x to the matrix equation (L - I)x = 0.

# %%
L=np.array([[0, 1/2, 1/4, 1, 1/3],
           [1/3, 0, 1/4, 0, 0],
           [1/3, 1/2, 0, 0, 1/3],
           [1/3, 0, 1/4, 0, 1/3],
           [0,0,1/4,0,0]])
I=np.eye(5)
Z=np.zeros((5,1))
Aug=np.hstack(((L-I),Z))
print(Aug)
# Out:
# [[-1.          0.5         0.25        1.          0.33333333  0.        ]
#  [ 0.33333333 -1.          0.25        0.          0.          0.        ]
#  [ 0.33333333  0.5        -1.          0.          0.33333333  0.        ]
#  [ 0.33333333  0.          0.25       -1.          0.33333333  0.        ]
#  [ 0.          0.          0.25        0.         -1.          0.        ]]

# %%
reducedAug=rref(Aug)
print(reducedAug)
rA= - Aug[0][4]
rB= - Aug[1][4]
rC= - Aug[2][4]
rD= - Aug[3][4]
rE= - Aug[4][4]

print("rA=",rA)
print("rB=",rB)
print("rC=",rC)
print("rD=",rD)
print("rE=",rE)
# Out:
# [[ 1.          0.          0.          0.         -6.33333333 -0.        ]
#  [ 0.          1.          0.          0.         -3.11111111 -0.        ]
#  [ 0.          0.          1.          0.         -4.         -0.        ]
#  [ 0.          0.          0.          1.         -3.44444444 -0.        ]
#  [ 0.          0.          0.          0.          0.          0.        ]]
# rA= 6.333333333333326
# rB= 3.111111111111107
# rC= 3.9999999999999947
# rD= 3.44444444444444
# rE= -0.0

# %% [markdown]
# ## Exercise 3: Epidemic Dynamics – SIR model

# %% [markdown]
# #### Question 6
#
# The SIR model is a simple mathematical description of the spread of a disease in a population. It divides the (fixed) population of N individuals into four "compartments" which may vary as a function of time, t: <br>
#     • Susceptible S(t): not yet infected but can acquire the disease the next day; <br>
#     • Infected I(t): have the disease;<br>
#     • Recovered R(t): had the disease, have recovered, and now have immunity to it.<br>
#     • Deceased D(t): had the disease, and unfortunately, died.<br>
# The above information could be put together in a normalized vector, e.g., 𝐱𝑡 = [0.75 0.1 0.1 0.05].<br><br>
#
# Suppose the progression of the disease over each day is as follows:<br>
#     • Among susceptible population <br>
#          o 5% acquires the disease<br>
#          o 95% remains susceptible<br>
#     • Among infected population<br>
#          o 1% dies<br>
#          o 10% recovers with immunity<br>
#          o 4% recover without immunity (i.e., remain susceptible) <br>
#          o 85% remain infected <br>
#     • 100% of immune and dead people remain in their state<br>
#
# Write a matrix P containing the above information. Using the state of the disease given by vector 𝐱𝑡 above, what is the state of the disease the next day? Note that 𝐱𝑡+1 = 𝑃𝐱𝑡.

# %%
Xt=np.array([[0.75],[0.1],[0.1],[0.05]])
P=np.array([[0.95,0.04,0,0],
           [0.05,0.85,0,0],
           [0,0.10,1,0],
           [0,0.01,0,1]])

# %%
Xt1=np.matmul(P,Xt)
print("State of the disease the next day:\n",Xt1)
# Out:
# State of the disease the next day:
#  [[0.7165]
#  [0.1225]
#  [0.11  ]
#  [0.051 ]]

# %% [markdown]
# #### Question 7
# Assume 𝐱1 = [1 0 0 0]. Find the progression of the disease for each day from 𝑡 = 2 till 𝑡 = 200. For each of the compartments – S, I, R and D – plot the progression from day 1 to day 200 on the same plot.

# %%
X=[1,0,0,0]
Xn=[]
Xt=[X for X in range (2,201)]
S=[]
I=[]
R=[]
D=[]

t=2
Xn=X

while 2<=t<=200:
    Xn=P@Xn
    S.append(Xn[0]*100)
    I.append(Xn[1]*100)
    R.append(Xn[2]*100)
    D.append(Xn[3]*100)
    t+=1

# %%
plt.xlabel("Time /days")
plt.ylabel("Progression /%")
plt.plot(Xt,S,'r',label="Susceptible")
plt.plot(Xt,I,'b',label="Infected")
plt.plot(Xt,R,'g',label="Recovered")
plt.plot(Xt,D,'y',label="Deceased")
plt.title("Progression of the Disease\n")
plt.legend()
plt.show()
